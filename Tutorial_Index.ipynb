# %% [markdown]
# # 🧭 Deep Learning Tutorials – Index
#
# Welcome! Below are all tutorial notebooks with direct links to their rendered versions on **nbviewer**.
#
# | # | Topic | nbviewer Link |
# |---|--------|---------------|
# | 1 | [Perceptron Implementation](Tutorial01_Perceptron/tutorial1_solution.ipynb) | [View Online](https://nbviewer.org/github/USERNAME/deep-learning-tutorials/blob/main/Tutorial01_Perceptron/tutorial1_solution.ipynb) |
# | 2 | [Multi-Layer Perceptron (MLP)](Tutorial02_MLP/tutorial2_solution.ipynb) | [View Online](https://nbviewer.org/github/USERNAME/deep-learning-tutorials/blob/main/Tutorial02_MLP/tutorial2_solution.ipynb) |
# | 3 | [MNIST Neural Network](Tutorial03_MNIST/tutorial3_solution.ipynb) | [View Online](https://nbviewer.org/github/USERNAME/deep-learning-tutorials/blob/main/Tutorial03_MNIST/tutorial3_solution.ipynb) |
# | 4 | [Data Augmentation](Tutorial04_DataAugmentation/tutorial4_solution.ipynb) | [View Online](https://nbviewer.org/github/USERNAME/deep-learning-tutorials/blob/main/Tutorial04_DataAugmentation/tutorial4_solution.ipynb) |
# | 5 | [Convolutional Neural Network (CNN)](Tutorial05_CNN/tutorial5_solution.ipynb) | [View Online](https://nbviewer.org/github/USERNAME/deep-learning-tutorials/blob/main/Tutorial05_CNN/tutorial5_solution.ipynb) |
# | 6 | [Pretrained Models (Transfer Learning)](Tutorial06_PretrainedModels/tutorial6_solution.ipynb) | [View Online](https://nbviewer.org/github/USERNAME/deep-learning-tutorials/blob/main/Tutorial06_PretrainedModels/tutorial6_solution.ipynb) |
# | 7 | [Feature Extraction vs Fine-Tuning](Tutorial07_FeatureExtraction/tutorial7_solution.ipynb) | [View Online](https://nbviewer.org/github/USERNAME/deep-learning-tutorials/blob/main/Tutorial07_FeatureExtraction/tutorial7_solution.ipynb) |
# | 8 | [Object Detection (Faster R-CNN)](Tutorial08_ObjectDetection/tutorial8_solution.ipynb) | [View Online](https://nbviewer.org/github/USERNAME/deep-learning-tutorials/blob/main/Tutorial08_ObjectDetection/tutorial8_solution.ipynb) |

# %% [markdown]
# #### 🧑‍💻 To run locally
# ```bash
# conda env create -f environment.yml
# conda activate dl_tutorials
# jupyter notebook
# ```
#
# Each folder contains its own notebook and required code blocks.
